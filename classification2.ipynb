# %%
import pandas as pd

# %%
data=pd.read_csv("credit_risk_dataset.csv")

# %%
data.notnull()
# Out:
#        person_age  person_income  person_home_ownership  person_emp_length  \
# 0            True           True                   True               True
# 1            True           True                   True               True
# 2            True           True                   True               True
# 3            True           True                   True               True
# 4            True           True                   True               True
# ...           ...            ...                    ...                ...
# 32576        True           True                   True               True
# 32577        True           True                   True               True
# 32578        True           True                   True               True
# 32579        True           True                   True               True
# 32580        True           True                   True               True
#
# ...

# %%
data.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Google big query and google spanner

# %%
data.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
data.isnull().mean()*100
# Out:
# person_age                    0.000000
# person_income                 0.000000
# person_home_ownership         0.000000
# person_emp_length             2.747000
# loan_intent                   0.000000
# loan_grade                    0.000000
# loan_amnt                     0.000000
# loan_int_rate                 9.563856
# loan_status                   0.000000
# loan_percent_income           0.000000
# cb_person_default_on_file     0.000000
# cb_person_cred_hist_length    0.000000
# dtype: float64

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
data
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
data.hist(layout=(5,4),figsize=(20,15),bins=20)
# Out:
# array([[<Axes: title={'center': 'person_age'}>,
#         <Axes: title={'center': 'person_income'}>,
#         <Axes: title={'center': 'person_emp_length'}>,
#         <Axes: title={'center': 'loan_amnt'}>],
#        [<Axes: title={'center': 'loan_int_rate'}>,
#         <Axes: title={'center': 'loan_status'}>,
#         <Axes: title={'center': 'loan_percent_income'}>,
#         <Axes: title={'center': 'cb_person_cred_hist_length'}>],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
data.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
sns.scatterplot(x='person_age',y='person_income',data=data)
# Out:
# <Axes: xlabel='person_age', ylabel='person_income'>

# %%
data=data[data['person_age']<=90]

# %%
sns.lineplot(x='person_age',y='person_income',data=data)
plt.ylabel('Income')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
columns_to_remove=['person_home_ownership','loan_intent','loan_grade','cb_person_default_on_file']
df=data.drop(columns=columns_to_remove)

# %%
df
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 0              22          59000              123.0      35000          16.02
# 1              21           9600                5.0       1000          11.14
# 2              25           9600                1.0       5500          12.87
# 3              23          65500                4.0      35000          15.23
# 4              24          54400                8.0      35000          14.27
# ...           ...            ...                ...        ...            ...
# 32576          57          53000                1.0       5800          13.16
# 32577          54         120000                4.0      17625           7.49
# 32578          65          76000                3.0      35000          10.99
# 32579          56         150000                5.0      15000          11.48
# 32580          66          42000                2.0       6475           9.99
#
# ...

# %%
target=df['loan_status']

# %%
df=df.drop(columns='loan_status')

# %%
df
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 0              22          59000              123.0      35000          16.02
# 1              21           9600                5.0       1000          11.14
# 2              25           9600                1.0       5500          12.87
# 3              23          65500                4.0      35000          15.23
# 4              24          54400                8.0      35000          14.27
# ...           ...            ...                ...        ...            ...
# 32576          57          53000                1.0       5800          13.16
# 32577          54         120000                4.0      17625           7.49
# 32578          65          76000                3.0      35000          10.99
# 32579          56         150000                5.0      15000          11.48
# 32580          66          42000                2.0       6475           9.99
#
# ...

# %%
df.corr()
# Out:
#                             person_age  person_income  person_emp_length  \
# person_age                    1.000000       0.141363           0.168997
# person_income                 0.141363       1.000000           0.158595
# person_emp_length             0.168997       0.158595           1.000000
# loan_amnt                     0.055849       0.324745           0.110850
# loan_int_rate                 0.010372      -0.003893          -0.056440
# loan_percent_income          -0.039566      -0.297596          -0.055080
# cb_person_cred_hist_length    0.877578       0.122739           0.146092
#
#                             loan_amnt  loan_int_rate  loan_percent_income  \
# person_age                   0.055849       0.010372            -0.039566
# person_income                0.324745      -0.003893            -0.297596
# person_emp_length            0.110850      -0.056440            -0.055080
# loan_amnt                    1.000000       0.145972             0.577362
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.lineplot(x='person_age',y='cb_person_cred_hist_length',data=df)
plt.xlabel('Age')
plt.ylabel('Credit Card Length')
# Out:
# Text(0, 0.5, 'Credit Card Length')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df,target,test_size=0.2,random_state=42)

# %% [markdown]
# # Lgistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
lg=LogisticRegression()
lg.fit(x_train,y_train)
# Out:
# C:\Users\bhara\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

# %%
y_pred=lg.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
disp=ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8252138990745591

# %% [markdown]
# # KNeighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn=KNeighborsClassifier(n_neighbors=6)
kn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
y_pred=kn.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
disp=ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Greens)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8479133927012398

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
disp=ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Reds)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8327221931203073

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb=GaussianNB()

# %%
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=nb.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
disp=ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8143879867295268

# %% [markdown]
# # Accuracy score of Logistic regression:0.8131657063034747
# # Accuracy Score of KNearest Neighbors:0.8479133927012398
# # Accuracy score of Decision Tree:0.8318491356731272
# # Accuracy score of Naive Bayes:0.8143879867295268

# %% [markdown]
# # KNearest Neighbor has the Better Accurcy Score

# %%
plt.figure(figsize=(20,12))
for i,feature in enumerate(df.columns,1):
    plt.subplot(4, 2, i)
    sns.lineplot(x=feature,y='loan_status',data=data)
plt.tight_layout()
plt.show()

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE
x_train, x_test, y_train, y_test = train_test_split(df, target, test_size=0.3, random_state=42)

# %%
smote = SMOTE(random_state=42)
x_resampled, y_resampled = smote.fit_resample(x_train, y_train)

# %%
x_train.shape
# Out:
# (20043, 7)

# %%
x_resampled.shape
# Out:
# (31372, 7)
